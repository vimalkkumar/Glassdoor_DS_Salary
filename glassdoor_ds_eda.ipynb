# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataset = pd.read_csv('Data/gd_ds_salary_cleaned_data.csv')

# %%
dataset.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          742 non-null    object
#  1   Salary Estimate    742 non-null    object
#  2   Job Description    742 non-null    object
#  3   Rating             742 non-null    float64
#  4   Company Name       742 non-null    object
#  5   Location           742 non-null    object
#  6   Headquarters       742 non-null    object
#  7   Size               742 non-null    object
#  8   Founded            742 non-null    int64
#  9   Type of ownership  742 non-null    object
#  10  Industry           742 non-null    object
#  11  Sector             742 non-null    object
#  12  Revenue            742 non-null    object
#  13  Competitors        742 non-null    object
#  14  Hourly             742 non-null    int64
#  15  Employer Provided  742 non-null    int64
# ...

# %%
dataset.nunique(axis = 0)
# Out:
# Job Title            264
# Salary Estimate      416
# Job Description      463
# Rating                31
# Company Name         343
# Location             200
# Headquarters         198
# Size                   9
# Founded              102
# Type of ownership     11
# Industry              60
# Sector                25
# Revenue               14
# Competitors          128
# Hourly                 2
# Employer Provided      2
# Min Salary           114
# Max Salary           160
# Average Salary       225
# Company Name Text    343
# State                 37
# Same State             2
# Age                  102
# Python                 2
# R                      2
# AWS                    2
# Azure                  2
# Spark                  2
# Excel                  2
# Job Sample             6
# Seniority              3
# Desc Length          443
# Comp Num               5
# dtype: int64

# %%
dataset.describe().T
# Out:
#                    count         mean          std    min     25%     50%  \
# Rating             742.0     3.618868     0.801210   -1.0     3.3     3.7
# Founded            742.0  1837.154987   497.183763   -1.0  1939.0  1988.0
# Hourly             742.0     0.032345     0.177034    0.0     0.0     0.0
# Employer Provided  742.0     0.022911     0.149721    0.0     0.0     0.0
# Min Salary         742.0    74.719677    30.980593   15.0    52.0    69.5
# Max Salary         742.0   128.149596    45.220324   16.0    96.0   124.0
# Average Salary     742.0   100.626011    38.855948   13.5    73.5    97.5
# Same State         742.0     0.557951     0.496965    0.0     0.0     1.0
# Age                742.0    47.524259    53.839080   -1.0    12.0    25.0
# Python             742.0     0.528302     0.499535    0.0     0.0     1.0
# R                  742.0     0.002695     0.051882    0.0     0.0     0.0
# AWS                742.0     0.237197     0.425651    0.0     0.0     0.0
# ...

# %%
dataset.isnull().sum()
# Out:
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# Hourly               0
# Employer Provided    0
# Min Salary           0
# Max Salary           0
# Average Salary       0
# Company Name Text    0
# State                0
# Same State           0
# Age                  0
# Python               0
# R                    0
# AWS                  0
# Azure                0
# Spark                0
# Excel                0
# Job Sample           0
# Seniority            0
# Desc Length          0
# Comp Num             0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Hourly', 'Employer Provided', 'Min Salary', 'Max Salary',
#        'Average Salary', 'Company Name Text', 'State', 'Same State', 'Age',
#        'Python', 'R', 'AWS', 'Azure', 'Spark', 'Excel', 'Job Sample',
#        'Seniority', 'Desc Length', 'Comp Num'],
#       dtype='object')

# %%
dataset['Rating'].hist()
# Out:
# <AxesSubplot:>

# %%
dataset['Average Salary'].hist()
# Out:
# <AxesSubplot:>

# %%
dataset['Age'].hist()
# Out:
# <AxesSubplot:>

# %%
dataset['Desc Length'].hist()
# Out:
# <AxesSubplot:>

# %%
dataset['Comp Num'].hist()
# Out:
# <AxesSubplot:>

# %%
dataset.boxplot(column = ['Age'])
# Out:
# <AxesSubplot:>

# %%
dataset.boxplot(column = ['Rating'])
# Out:
# <AxesSubplot:>

# %%
dataset.boxplot(column = ['Average Salary'])
# Out:
# <AxesSubplot:>

# %%
# Checking the correlation between Age, Average Salary, Rating and Description Length
corr = dataset[['Age', 'Average Salary', 'Desc Length', 'Rating', 'Comp Num']].corr()

# %%
sbn.heatmap(corr, annot = True, cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
cat_data = dataset[['Size', 'Type of ownership', 'Sector', 'Revenue', 'State', 'Same State', 'Python', 'R', 'AWS', 'Azure', 'Spark', 'Excel', 'Job Sample', 'Seniority']]

# %%
for i in cat_data.columns:
    cat_num = cat_data[i].value_counts()
    print('Graph for %s: total = %d' % (i, len(cat_num)))
    fig = sbn.barplot(x = cat_num.index, y = cat_num)
    fig.set_xticklabels(fig.get_xticklabels(), rotation = 90)
    plt.show()
# Out:
# Graph for Size: total = 9
# Graph for Type of ownership: total = 11
# Graph for Sector: total = 25
# Graph for Revenue: total = 14
# Graph for State: total = 37
# Graph for Same State: total = 2
# Graph for Python: total = 2
# Graph for R: total = 2
# Graph for AWS: total = 2
# Graph for Azure: total = 2
# Graph for Spark: total = 2
# Graph for Excel: total = 2
# Graph for Job Sample: total = 6
# Graph for Seniority: total = 3

# %%
for i in dataset[['Location' ,'Headquarters', 'Industry', 'Company Name Text']].columns:
    cat_num = dataset[i].value_counts()[:20]
    print('Graph for %s: total = %d' % (i, len(cat_num)))
    fig = sbn.barplot(x = cat_num.index, y = cat_num)
    fig.set_xticklabels(fig.get_xticklabels(), rotation = 90)
    plt.show()
# Out:
# Graph for Location: total = 20
# Graph for Headquarters: total = 20
# Graph for Industry: total = 20
# Graph for Company Name Text: total = 20

# %%
pd.pivot_table(dataset, index = 'Job Sample', values = 'Average Salary')
# Out:
#                 Average Salary
# Job Sample
# analyst              65.786408
# data scientist      117.564516
# director            166.117647
# manager              84.022727
# mle                 126.431818
# na                   92.421405

# %%
pd.pivot_table(dataset, index = ['Job Sample', 'Seniority'], values = 'Average Salary')
# Out:
#                           Average Salary
# Job Sample     Seniority
# analyst        junior          53.250000
#                na              61.270270
#                senior          79.092593
# data scientist junior         106.500000
#                na             107.043011
#                senior         138.956522
# director       na             166.117647
# manager        na              84.022727
# mle            na             119.133333
#                senior         142.071429
# na             na              81.970732
#                senior         115.212766

# %%
pd.pivot_table(dataset, index = 'State', values = 'Average Salary').sort_values('Average Salary', ascending = False)
# Out:
#        Average Salary
# State
# CA         123.513158
# IL         116.662500
# DC         110.181818
# MA         106.281553
# NJ         104.558824
# MI         100.250000
# RI         100.000000
# NY          98.652778
# NC          98.452381
# MD          97.357143
# KY          97.000000
# VA          95.621951
# UT          94.150000
# WA          93.190476
# PA          92.560606
# OR          92.125000
# IN          90.300000
# TX          89.392857
# OH          87.571429
# TN          87.115385
# KS          87.000000
# AZ          85.666667
# MN          85.500000
# MO          84.722222
# GA          80.666667
# IA          78.900000
# FL          77.625000
# CO          77.045455
# NM          74.333333
# WI          73.300000
# CT          71.100000
# SC          60.500000
# AL          57.937500
# ID          56.250000
# LA          52.250000
# NE          41.000000
# DE          27.500000

# %%
pd.pivot_table(dataset, index = ['State', 'Job Sample'], values = 'Average Salary', aggfunc = 'count')
# Out:
#                       Average Salary
# State Job Sample
# AL    analyst                      5
#       na                           3
# AZ    analyst                      1
#       data scientist               1
#       na                           7
# CA    analyst                     18
#       data scientist              68
#       manager                      9
#       mle                          5
#       na                          52
# CO    analyst                      1
#       data scientist               3
#       mle                          1
#       na                           6
# CT    data scientist               2
#       na                           3
# DC    analyst                      2
#       data scientist               5
#       na                           4
# DE    na                           6
# FL    analyst                      6
#       data scientist               7
#       na                           3
# GA    data scientist               3
# ...

# %%
pd.pivot_table(dataset[dataset['Job Sample'] == 'data scientist'], index = 'State', values = 'Average Salary').sort_values('Average Salary', ascending = False)
# Out:
#        Average Salary
# State
# DC         149.000000
# CA         142.522059
# UT         140.500000
# MO         127.666667
# IL         117.233333
# NC         117.000000
# NY         115.250000
# MA         113.750000
# WI         113.500000
# PA         113.333333
# MD         109.115385
# CO         108.666667
# VA         108.416667
# NJ         106.875000
# MI         106.625000
# OH         105.285714
# TX         100.730769
# WA          99.764706
# OR          98.500000
# FL          97.357143
# TN          96.000000
# IN          84.500000
# KY          84.000000
# CT          84.000000
# GA          81.333333
# NM          74.333333
# AZ          69.500000

# %%
pd.pivot_table(dataset, index = 'Rating', values = 'Average Salary').sort_values('Average Salary', ascending = False)
# Out:
#         Average Salary
# Rating
# -1.0        136.181818
#  5.0        134.700000
#  2.5        120.000000
#  4.5        117.714286
#  4.1        116.368421
#  3.9        113.071429
#  2.6        109.083333
#  4.4        108.606061
#  3.2        105.500000
#  4.0        105.340426
#  3.5        104.897959
#  3.7        104.131148
#  4.7        103.983871
#  4.3        102.468750
#  3.3        101.858974
#  4.2        100.442308
#  2.2         97.750000
#  4.6         97.250000
#  3.8         96.811475
#  2.1         95.900000
#  3.4         93.011364
#  1.9         87.500000
#  3.1         86.580000
#  3.0         85.588235
#  3.6         85.467391
#  2.8         83.928571
#  2.7         83.250000
#  2.3         81.500000
#  2.9         81.138889
#  4.8         80.277778
#  2.4         60.214286

# %%
pd.pivot_table(dataset, index = 'Location', values = 'Average Salary').sort_values('Average Salary', ascending = False)
# Out:
#                                    Average Salary
# Location
# Bellevue, WA                           184.500000
# Lake Forest, IL                        179.500000
# Mountain View, CA                      177.187500
# Novato, CA                             168.000000
# Burbank, CA                            164.000000
# Emeryville, CA                         153.000000
# Newark, NJ                             146.000000
# Fort Lee, NJ                           145.666667
# Jersey City, NJ                        144.750000
# Saint Louis, MO                        143.500000
# Brisbane, CA                           143.500000
# San Jose, CA                           142.461538
# Marlborough, MA                        142.000000
# Cupertino, CA                          142.000000
# Foster City, CA                        139.500000
# Natick, MA                             139.500000
# Plano, TX                              139.000000
# San Francisco, CA                      137.244898
# ...

# %%
pd.pivot_table(dataset, index = 'Size', values = 'Average Salary').sort_values('Average Salary', ascending = False)
# Out:
#                          Average Salary
# Size
# Unknown                      128.111111
# -1                           117.500000
# 10000+ employees             112.230769
# 51 to 200 employees          111.351064
# 1 to 50 employees            102.306452
# 201 to 500 employees         100.247863
# 5001 to 10000 employees       96.552632
# 1001 to 5000 employees        92.916667
# 501 to 1000 employees         90.753731

# %%
pd.pivot_table(dataset, index = 'Type of ownership', values = 'Average Salary').sort_values('Average Salary', ascending = False)
# Out:
#                                 Average Salary
# Type of ownership
# -1                                  117.500000
# Company - Public                    110.893782
# Subsidiary or Business Segment      110.573529
# College / University                107.615385
# Company - Private                   101.776829
# Government                           84.300000
# School / School District             77.750000
# Other Organization                   77.500000
# Nonprofit Organization               68.281818
# Hospital                             54.000000
# Unknown                              39.500000

# %%
pd.pivot_table(dataset, index = 'Industry', values = 'Average Salary').sort_values('Average Salary', ascending = False)
# Out:
#                                           Average Salary
# Industry
# Other Retail Stores                           163.500000
# Motion Picture Production & Distribution      146.000000
# Financial Analytics & Research                145.125000
# Health, Beauty, & Fitness                     139.500000
# Telecommunications Services                   131.500000
# Brokerage Services                            129.000000
# Auctions & Galleries                          128.000000
# Internet                                      123.810345
# Investment Banking & Asset Management         118.400000
# TV Broadcast & Cable Networks                 117.750000
# Enterprise Software & Network Solutions       115.369048
# Computer Hardware & Software                  115.194915
# -1                                            114.650000
# Accounting                                    113.500000
# Biotech & Pharmaceuticals                     111.767857
# ...

# %%
pd.pivot_table(dataset, index = 'Sector', values = 'Average Salary').sort_values('Average Salary', ascending = False)
# Out:
#                                     Average Salary
# Sector
# Media                                   116.666667
# -1                                      114.650000
# Accounting & Legal                      113.500000
# Information Technology                  113.191667
# Biotech & Pharmaceuticals               111.767857
# Insurance                               105.942029
# Real Estate                             104.750000
# Mining & Metals                         104.000000
# Telecommunications                      102.333333
# Education                               100.739130
# Consumer Services                        99.875000
# Retail                                   99.666667
# Transportation & Logistics               99.312500
# Aerospace & Defense                      99.060000
# Business Services                        97.701031
# Finance                                  97.369048
# Manufacturing                            84.044118
# ...

# %%
pd.pivot_table(dataset, index = 'Revenue', values = 'Average Salary').sort_values('Average Salary', ascending = False)
# Out:
#                                   Average Salary
# Revenue
# $5 to $10 million (USD)               126.111111
# $1 to $5 million (USD)                119.312500
# -1                                    117.500000
# $10+ billion (USD)                    115.165323
# Less than $1 million (USD)            108.625000
# $1 to $2 billion (USD)                104.533333
# Unknown / Non-Applicable              104.310345
# $50 to $100 million (USD)             100.565217
# $10 to $25 million (USD)              100.359375
# $2 to $5 billion (USD)                 94.730769
# $5 to $10 billion (USD)                94.184211
# $500 million to $1 billion (USD)       86.991228
# $100 to $500 million (USD)             83.153846
# $25 to $50 million (USD)               82.837500

# %%
pd.pivot_table(dataset, index = 'Python', values = 'Average Salary').sort_values('Average Salary', ascending = False)
# Out:
#         Average Salary
# Python
# 1           112.653061
# 0            87.155714

# %%
pd.pivot_table(dataset, index = 'R', values = 'Average Salary').sort_values('Average Salary', ascending = False)
# Out:
#    Average Salary
# R
# 0      100.706757
# 1       70.750000

# %%
pd.pivot_table(dataset, index = 'AWS', values = 'Average Salary').sort_values('Average Salary', ascending = False)
# Out:
#      Average Salary
# AWS
# 1        112.559659
# 0         96.915194

# %%
pd.pivot_table(dataset, index = 'Azure', values = 'Average Salary').sort_values('Average Salary', ascending = False)
# Out:
#        Average Salary
# Azure
# 1          104.009259
# 0          100.360465

# %%
pd.pivot_table(dataset, index = 'Spark', values = 'Average Salary').sort_values('Average Salary', ascending = False)
# Out:
#        Average Salary
# Spark
# 1          113.347305
# 0           96.931304

# %%
pd.pivot_table(dataset, index = 'Excel', values = 'Average Salary').sort_values('Average Salary', ascending = False)
# Out:
#        Average Salary
# Excel
# 0          102.953390
# 1           98.502577

# %%
pd.pivot_table(dataset, index = 'Comp Num', values = 'Average Salary').sort_values('Average Salary', ascending = False)
# Out:
#           Average Salary
# Comp Num
# 2             106.865854
# 1             106.208333
# 3             105.504386
# 0              97.602174
# 4              56.500000

# %%
plt.figure(figsize = (8,8))
sbn.scatterplot(x = dataset['Rating'], y = dataset['Average Salary'], hue = dataset['Comp Num'], palette= 'rainbow')
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Average Salary'>

# %%
plt.figure(figsize = (8, 8))
sbn.relplot(x = dataset['Rating'], y = dataset['Average Salary'])

# %%
plt.figure(figsize = (8, 8))
sbn.relplot(x = dataset['Desc Length'], y = dataset['Average Salary'])

# %%
plt.figure(figsize = (8, 8))
fig = sbn.barplot(x = 'Revenue', y = 'Age', data = dataset)
fig.set_xticklabels(fig.get_xticklabels(), rotation = 90)
plt.show()

# %%
plt.figure(figsize =(8, 8))
sbn.catplot(y = 'State', kind = 'count', data = dataset)
plt.show()

# %%
sbn.catplot(y = 'Sector', kind = 'count', data = dataset)
plt.show()

# %%
dataset.hist(bins = 40, figsize=(20, 20))
plt.show()

# %%
plt.figure(figsize = (7, 9))
sbn.boxenplot(y = dataset['Average Salary'])
plt.show()
